# %%
import numpy as np 
import pandas as pd

# %%
panicd = pd.read_csv(r"C:\Users\Shantanu jha\Desktop\panic_disorder_dataset_testing.csv\panic_disorder_dataset_testing.csv")

# %%
panicd
# Out:
#        Participant ID  Age  Gender Family History Personal History  \
# 0                   1   41    Male            Yes               No
# 1                   2   20  Female            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes               No
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 0                  High  Shortness of breath      Mild           Mild
# ...

# %%
panicd.head()
# Out:
#    Participant ID  Age  Gender Family History Personal History  \
# 0               1   41    Male            Yes               No
# 1               2   20  Female            Yes               No
# 2               3   32    Male            Yes              Yes
# 3               4   41  Female            Yes              Yes
# 4               5   36  Female            Yes               No
#
#   Current Stressors             Symptoms  Severity Impact on Life  \
# 0              High  Shortness of breath      Mild           Mild
# 1               Low  Shortness of breath      Mild    Significant
# 2              High        Panic attacks    Severe           Mild
# 3          Moderate  Shortness of breath  Moderate    Significant
# 4              High           Chest pain    Severe    Significant
#
#   Demographics Medical History  Psychiatric History Substance Use  \
# 0        Urban        Diabetes     Bipolar disorder       Alcohol
# ...

# %%
panicd['Personal History'][4] = 'No'
# Out:
# C:\Users\Shantanu jha\AppData\Local\Temp\ipykernel_26264\1709896144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   panicd['Personal History'][4] = 'No'

# %%
panicd
# Out:
#        Participant ID  Age  Gender Family History Personal History  \
# 0                   1   41    Male            Yes               No
# 1                   2   20  Female            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes               No
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 0                  High  Shortness of breath      Mild           Mild
# ...

# %%
panicd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Participant ID            20000 non-null  int64
#  1   Age                       20000 non-null  int64
#  2   Gender                    20000 non-null  object
#  3   Family History            20000 non-null  object
#  4   Personal History          20000 non-null  object
#  5   Current Stressors         20000 non-null  object
#  6   Symptoms                  20000 non-null  object
#  7   Severity                  20000 non-null  object
#  8   Impact on Life            20000 non-null  object
#  9   Demographics              20000 non-null  object
#  10  Medical History           20000 non-null  object
#  11  Psychiatric History       20000 non-null  object
#  12  Substance Use             20000 non-null  object
# ...

# %%
panicd.dtypes
# Out:
# Participant ID               int64
# Age                          int64
# Gender                      object
# Family History              object
# Personal History            object
# Current Stressors           object
# Symptoms                    object
# Severity                    object
# Impact on Life              object
# Demographics                object
# Medical History             object
# Psychiatric History         object
# Substance Use               object
# Coping Mechanisms           object
# Social Support              object
# Lifestyle Factors           object
# Panic Disorder Diagnosis     int64
# dtype: object

# %%
panicd['Age']
# Out:
# 0        45
# 1        20
# 2        32
# 3        41
# 4        36
#          ..
# 19995    31
# 19996    27
# 19997    21
# 19998    28
# 19999    22
# Name: Age, Length: 20000, dtype: int64

# %%
panicd.describe()
# Out:
#        Participant ID           Age  Panic Disorder Diagnosis
# count    20000.000000  20000.000000              20000.000000
# mean     10000.500000     41.489250                  0.042050
# std       5773.647028     13.887773                  0.200708
# min          1.000000     18.000000                  0.000000
# 25%       5000.750000     29.000000                  0.000000
# 50%      10000.500000     42.000000                  0.000000
# 75%      15000.250000     54.000000                  0.000000
# max      20000.000000     65.000000                  1.000000

# %%
panicd['Age'][0]=45
# Out:
# C:\Users\Shantanu jha\AppData\Local\Temp\ipykernel_15416\266502599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   panicd['Age'][0]=45

# %%
panicd.head()
# Out:
#    Participant ID  Age  Gender Family History Personal History  \
# 0               1   41    Male            Yes               No
# 1               2   20  Female            Yes               No
# 2               3   32    Male            Yes              Yes
# 3               4   41  Female            Yes              Yes
# 4               5   36  Female            Yes               No
#
#   Current Stressors             Symptoms  Severity Impact on Life  \
# 0              High  Shortness of breath      Mild           Mild
# 1               Low  Shortness of breath      Mild    Significant
# 2              High        Panic attacks    Severe           Mild
# 3          Moderate  Shortness of breath  Moderate    Significant
# 4              High           Chest pain    Severe    Significant
#
#   Demographics Medical History  Psychiatric History Substance Use  \
# 0        Urban        Diabetes     Bipolar disorder       Alcohol
# ...

# %%
panicd.index
# Out:
# RangeIndex(start=0, stop=20000, step=1)

# %%
panicd.columns
# Out:
# Index(['Participant ID', 'Age', 'Gender', 'Family History', 'Personal History',
#        'Current Stressors', 'Symptoms', 'Severity', 'Impact on Life',
#        'Demographics', 'Medical History', 'Psychiatric History',
#        'Substance Use', 'Coping Mechanisms', 'Social Support',
#        'Lifestyle Factors', 'Panic Disorder Diagnosis'],
#       dtype='object')

# %%
panicd.to_numpy
# Out:
# <bound method DataFrame.to_numpy of        Participant ID  Age  Gender Family History Personal History  \
# 0                   1   45    Male            Yes               No
# 1                   2   20  Female            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes              yes
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# ...

# %%
panicd.T
# Out:
#                                         0                    1      \
# Participant ID                              1                    2
# Age                                        45                   20
# Gender                                   Male               Female
# Family History                            Yes                  Yes
# Personal History                           No                   No
# Current Stressors                        High                  Low
# Symptoms                  Shortness of breath  Shortness of breath
# Severity                                 Mild                 Mild
# Impact on Life                           Mild          Significant
# Demographics                            Urban                Urban
# Medical History                      Diabetes               Asthma
# Psychiatric History          Bipolar disorder     Anxiety disorder
# Substance Use                         Alcohol                Drugs
# ...

# %%
panicd.sort_index(axis=1,ascending= False)
# Out:
#                   Symptoms Substance Use Social Support  Severity  \
# 0      Shortness of breath       Alcohol            Low      Mild
# 1      Shortness of breath         Drugs           High      Mild
# 2            Panic attacks         Drugs       Moderate    Severe
# 3      Shortness of breath          None           High  Moderate
# 4               Chest pain          None            Low    Severe
# ...                    ...           ...            ...       ...
# 19995           Chest pain          None       Moderate  Moderate
# 19996        Panic attacks       Alcohol           High      Mild
# 19997            Dizziness       Alcohol       Moderate  Moderate
# 19998            Dizziness          None       Moderate      Mild
# 19999            Dizziness       Alcohol            Low    Severe
#
#        Psychiatric History Personal History  Participant ID  \
# 0         Bipolar disorder               No               1
# ...

# %%
panicd.head()
# Out:
#    Participant ID  Age  Gender Family History Personal History  \
# 0               1   45    Male            Yes               No
# 1               2   20  Female            Yes               No
# 2               3   32    Male            Yes              Yes
# 3               4   41  Female            Yes              Yes
# 4               5   36  Female            Yes              yes
#
#   Current Stressors             Symptoms  Severity Impact on Life  \
# 0              High  Shortness of breath      Mild           Mild
# 1               Low  Shortness of breath      Mild    Significant
# 2              High        Panic attacks    Severe           Mild
# 3          Moderate  Shortness of breath  Moderate    Significant
# 4              High           Chest pain    Severe    Significant
#
#   Demographics Medical History  Psychiatric History Substance Use  \
# 0        Urban        Diabetes     Bipolar disorder       Alcohol
# ...

# %%
panicd['Age'][0]
# Out:
# 45

# %%
type(panicd['Age'])
# Out:
# pandas.core.series.Series

# %%
panicd.loc[0]['Age']
# Out:
# 45

# %%
panicd.loc[panicd['Age']<45]
# Out:
#        Participant ID  Age  Gender Family History Personal History  \
# 1                   2   20  Female            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes               No
# 5                   6   23  Female            Yes              Yes
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 1                   Low  Shortness of breath      Mild    Significant
# ...

# %%
panicd.loc[(panicd['Age']<45) &(panicd['Gender']=='Male')]
# Out:
#        Participant ID  Age Gender Family History Personal History  \
# 2                   3   32   Male            Yes              Yes
# 6                   7   34   Male            Yes              Yes
# 13                 14   41   Male            Yes               No
# 15                 16   39   Male            Yes               No
# 16                 17   38   Male            Yes              Yes
# ...               ...  ...    ...            ...              ...
# 19990           19991   24   Male             No               No
# 19991           19992   27   Male            Yes               No
# 19994           19995   27   Male            Yes              Yes
# 19996           19997   27   Male             No              Yes
# 19998           19999   28   Male             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 2                  High        Panic attacks    Severe           Mild
# ...

# %%
panicd.loc[(panicd['Age']<45) &(panicd['Gender']=='Male') & (panicd['Personal History']=='Yes')]
# Out:
#        Participant ID  Age Gender Family History Personal History  \
# 2                   3   32   Male            Yes              Yes
# 6                   7   34   Male            Yes              Yes
# 16                 17   38   Male            Yes              Yes
# 19                 20   22   Male            Yes              Yes
# 43                 44   24   Male            Yes              Yes
# ...               ...  ...    ...            ...              ...
# 19988           19989   23   Male            Yes              Yes
# 19989           19990   35   Male            Yes              Yes
# 19994           19995   27   Male            Yes              Yes
# 19996           19997   27   Male             No              Yes
# 19998           19999   28   Male             No              Yes
#
#       Current Stressors                Symptoms Severity Impact on Life  \
# 2                  High           Panic attacks   Severe           Mild
# ...

# %%
panicd.drop(1)
# Out:
#        Participant ID  Age  Gender Family History Personal History  \
# 0                   1   45    Male            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes              yes
# 5                   6   23  Female            Yes              Yes
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 0                  High  Shortness of breath      Mild           Mild
# ...

# %%
panicd
# Out:
#        Participant ID  Age  Gender Family History Personal History  \
# 0                   1   45    Male            Yes               No
# 1                   2   20  Female            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes              yes
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 0                  High  Shortness of breath      Mild           Mild
# ...

# %%
panicd.drop('Age',axis = 1)
# Out:
#        Participant ID  Gender Family History Personal History  \
# 0                   1    Male            Yes               No
# 1                   2  Female            Yes               No
# 2                   3    Male            Yes              Yes
# 3                   4  Female            Yes              Yes
# 4                   5  Female            Yes               No
# ...               ...     ...            ...              ...
# 19995           19996  Female            Yes              Yes
# 19996           19997    Male             No              Yes
# 19997           19998  Female             No               No
# 19998           19999    Male             No              Yes
# 19999           20000  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 0                  High  Shortness of breath      Mild           Mild
# 1                   Low  Shortness of breath      Mild    Significant
# ...

# %%
panicd
# Out:
#        Participant ID  Age  Gender Family History Personal History  \
# 0                   1   45    Male            Yes               No
# 1                   2   20  Female            Yes               No
# 2                   3   32    Male            Yes              Yes
# 3                   4   41  Female            Yes              Yes
# 4                   5   36  Female            Yes              yes
# ...               ...  ...     ...            ...              ...
# 19995           19996   31  Female            Yes              Yes
# 19996           19997   27    Male             No              Yes
# 19997           19998   21  Female             No               No
# 19998           19999   28    Male             No              Yes
# 19999           20000   22  Female             No              Yes
#
#       Current Stressors             Symptoms  Severity Impact on Life  \
# 0                  High  Shortness of breath      Mild           Mild
# ...

# %%
panicd['Symptoms'].value_counts()
# Out:
# Chest pain                4087
# Dizziness                 4035
# Panic attacks             3980
# Shortness of breath       3970
# Fear of losing control    3928
# Name: Symptoms, dtype: int64

# %%
panicd.value_counts()
# Out:
# Participant ID  Age  Gender  Family History  Personal History  Current Stressors  Symptoms                Severity  Impact on Life  Demographics  Medical History  Psychiatric History  Substance Use  Coping Mechanisms  Social Support  Lifestyle Factors  Panic Disorder Diagnosis
# 1               41   Male    Yes             No                High               Shortness of breath     Mild      Mild            Urban         Diabetes         Bipolar disorder     Alcohol        Seeking therapy    Low             Exercise           0                           1
# 13331           49   Male    No              Yes               Low                Fear of losing control  Mild      Mild            Urban         None             Bipolar disorder     Alcohol        Seeking therapy    Moderate        Sleep quality      0                           1
# ...

# %%
panicd.loc[(panicd['Age']<45) &(panicd['Gender']=='Male') & (panicd['Personal History']=='Yes')].value_counts
# Out:
# <bound method DataFrame.value_counts of        Participant ID  Age Gender Family History Personal History  \
# 2                   3   32   Male            Yes              Yes
# 6                   7   34   Male            Yes              Yes
# 16                 17   38   Male            Yes              Yes
# 19                 20   22   Male            Yes              Yes
# 43                 44   24   Male            Yes              Yes
# ...               ...  ...    ...            ...              ...
# 19988           19989   23   Male            Yes              Yes
# 19989           19990   35   Male            Yes              Yes
# 19994           19995   27   Male            Yes              Yes
# 19996           19997   27   Male             No              Yes
# 19998           19999   28   Male             No              Yes
#
#       Current Stressors                Symptoms Severity Impact on Life  \
# ...

# %%
panicd.sort_values(by = ['Age'],ascending= False ).head()
# Out:
#       Participant ID  Age  Gender Family History Personal History  \
# 1735            1736   65  Female            Yes               No
# 9563            9564   65    Male             No               No
# 4343            4344   65    Male            Yes              Yes
# 1191            1192   65    Male            Yes               No
# 7512            7513   65    Male             No               No
#
#      Current Stressors                Symptoms  Severity Impact on Life  \
# 1735              High               Dizziness    Severe    Significant
# 9563              High              Chest pain      Mild           Mild
# 4343              High  Fear of losing control  Moderate    Significant
# 1191               Low              Chest pain  Moderate           Mild
# 7512               Low  Fear of losing control      Mild           Mild
#
#      Demographics Medical History  Psychiatric History Substance Use  \
# ...

# %%
panicd.nlargest(4,['Age'])
# Out:
#      Participant ID  Age  Gender Family History Personal History  \
# 23               24   65    Male            Yes               No
# 78               79   65  Female            Yes               No
# 109             110   65    Male            Yes               No
# 122             123   65  Female             No               No
#
#     Current Stressors                Symptoms Severity Impact on Life  \
# 23               High           Panic attacks     Mild    Significant
# 78                Low              Chest pain     Mild    Significant
# 109              High  Fear of losing control   Severe    Significant
# 122               Low              Chest pain     Mild           Mild
#
#     Demographics Medical History  Psychiatric History Substance Use  \
# 23         Rural          Asthma  Depressive disorder       Alcohol
# 78         Urban   Heart disease     Anxiety disorder          None
# 109        Rural            None  Depressive disorder       Alcohol
# ...

# %%
panicd.head()
# Out:
#    Participant ID  Age  Gender Family History Personal History  \
# 0               1   41    Male            Yes               No
# 1               2   20  Female            Yes               No
# 2               3   32    Male            Yes              Yes
# 3               4   41  Female            Yes              Yes
# 4               5   36  Female            Yes               No
#
#   Current Stressors             Symptoms  Severity Impact on Life  \
# 0              High  Shortness of breath      Mild           Mild
# 1               Low  Shortness of breath      Mild    Significant
# 2              High        Panic attacks    Severe           Mild
# 3          Moderate  Shortness of breath  Moderate    Significant
# 4              High           Chest pain    Severe    Significant
#
#   Demographics Medical History  Psychiatric History Substance Use  \
# 0        Urban        Diabetes     Bipolar disorder       Alcohol
# ...

# %%
panicd.groupby('Age')['Participant ID'].count()
# Out:
# Age
# 18    425
# 19    429
# 20    412
# 21    434
# 22    431
# 23    440
# 24    431
# 25    392
# 26    422
# 27    370
# 28    419
# 29    401
# 30    447
# 31    397
# 32    446
# 33    382
# 34    417
# 35    396
# 36    408
# 37    419
# 38    396
# 39    412
# 40    400
# 41    436
# 42    446
# 43    428
# 44    412
# 45    399
# 46    447
# 47    385
# 48    437
# 49    409
# 50    432
# 51    412
# 52    375
# 53    406
# 54    426
# 55    413
# 56    450
# 57    414
# 58    411
# 59    445
# 60    433
# 61    416
# 62    417
# 63    412
# 64    399
# 65    414
# Name: Participant ID, dtype: int64

# %%
panicd.groupby('Current Stressors')['Participant ID'].count()
# Out:
# Current Stressors
# High        6597
# Low         6708
# Moderate    6695
# Name: Participant ID, dtype: int64

# %%
panicd.value_counts()
# Out:
# Participant ID  Age  Gender  Family History  Personal History  Current Stressors  Symptoms                Severity  Impact on Life  Demographics  Medical History  Psychiatric History  Substance Use  Coping Mechanisms  Social Support  Lifestyle Factors  Panic Disorder Diagnosis
# 1               41   Male    Yes             No                High               Shortness of breath     Mild      Mild            Urban         Diabetes         Bipolar disorder     Alcohol        Seeking therapy    Low             Exercise           0                           1
# 13331           49   Male    No              Yes               Low                Fear of losing control  Mild      Mild            Urban         None             Bipolar disorder     Alcohol        Seeking therapy    Moderate        Sleep quality      0                           1
# ...

# %%
panicd.loc[(panicd['Age']<45) &(panicd['Gender']=='Male') & (panicd['Personal History']=='Yes')][['Participant ID', 'Age','Current Stressors']].head()
# Out:
#     Participant ID  Age Current Stressors
# 2                3   32              High
# 6                7   34              High
# 16              17   38          Moderate
# 19              20   22          Moderate
# 43              44   24          Moderate

# %%
panicd.isnull()
# Out:
#        Participant ID    Age  Gender  Family History  Personal History  \
# 0               False  False   False           False             False
# 1               False  False   False           False             False
# 2               False  False   False           False             False
# 3               False  False   False           False             False
# 4               False  False   False           False             False
# ...               ...    ...     ...             ...               ...
# 19995           False  False   False           False             False
# 19996           False  False   False           False             False
# 19997           False  False   False           False             False
# 19998           False  False   False           False             False
# 19999           False  False   False           False             False
#
#        Current Stressors  Symptoms  Severity  Impact on Life  Demographics  \
# ...

# %%
panicd.isna().any()
# Out:
# Participant ID              False
# Age                         False
# Gender                      False
# Family History              False
# Personal History            False
# Current Stressors           False
# Symptoms                    False
# Severity                    False
# Impact on Life              False
# Demographics                False
# Medical History             False
# Psychiatric History         False
# Substance Use               False
# Coping Mechanisms           False
# Social Support              False
# Lifestyle Factors           False
# Panic Disorder Diagnosis    False
# dtype: bool

# %%
panicd['Age'].mean()
# Out:
# 41.48925

# %%
panicd.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    41.238949
# Male      41.741764
# Name: Age, dtype: float64

# %%
panicd.loc[(panicd['Age']<45) &(panicd['Gender']=='Male') & (panicd['Personal History']=='Yes')].head()
# Out:
#     Participant ID  Age Gender Family History Personal History  \
# 2                3   32   Male            Yes              Yes
# 6                7   34   Male            Yes              Yes
# 16              17   38   Male            Yes              Yes
# 19              20   22   Male            Yes              Yes
# 43              44   24   Male            Yes              Yes
#
#    Current Stressors             Symptoms Severity Impact on Life  \
# 2               High        Panic attacks   Severe           Mild
# 6               High  Shortness of breath   Severe           Mild
# 16          Moderate           Chest pain     Mild           Mild
# 19          Moderate            Dizziness   Severe       Moderate
# 43          Moderate        Panic attacks   Severe    Significant
#
#    Demographics Medical History  Psychiatric History Substance Use  \
# 2         Rural   Heart disease     Bipolar disorder         Drugs
# ...

# %%
panicd.loc[(panicd['Current Stressors']=='Moderate')][['Medical History','Participant ID']].groupby('Medical History').count()
# Out:
#                  Participant ID
# Medical History
# Asthma                     1649
# Diabetes                   1668
# Heart disease              1746
# None                       1632

# %%
panicd.loc[(panicd['Current Stressors']=='High')][['Medical History','Participant ID']].groupby('Medical History').count()
# Out:
#                  Participant ID
# Medical History
# Asthma                     1663
# Diabetes                   1638
# Heart disease              1652
# None                       1644

# %%
panicd.loc[(panicd['Current Stressors']=='Low')][['Medical History','Participant ID']].groupby('Medical History').count()
# Out:
#                  Participant ID
# Medical History
# Asthma                     1691
# Diabetes                   1680
# Heart disease              1612
# None                       1725
